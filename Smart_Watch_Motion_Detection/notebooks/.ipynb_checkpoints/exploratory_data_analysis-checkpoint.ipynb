# %%
import pickle
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def read_pickle(path):
    
    input_file = open(path,'rb')
    variable = pickle.load(input_file)
    input_file.close()
    return(variable)

# %%
# Read in data
data = read_pickle('../data/watch/processed_data/train_df.pkl')

# %%
data.columns
# Out:
# Index(['subject_id', 'activity_class', 'timestamp', 'accel_x', 'accel_y',
#        'accel_z', 'gyro_x', 'gyro_y', 'gyro_z', 'is_exercise', 'time_period'],
#       dtype='object')

# %%
# Split features and target
x_train = data.drop('is_exercise', axis = 1)
y_train = data['is_exercise']

# %% [markdown]
# ## Time-Series EDA

# %%
# library & dataset
import seaborn as sns
#df = sns.load_dataset('iris')

# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="time_period", y="accel_x", data=data[data['subject_id']==1650], 
           fit_reg=False, hue='is_exercise', legend=False, height=5, aspect=2)

sns.lmplot( x="time_period", y="accel_y", data=data[data['subject_id']==1650], 
           fit_reg=False, hue='is_exercise', legend=False, height=5, aspect=2)

sns.lmplot( x="time_period", y="accel_z", data=data[data['subject_id']==1650], 
           fit_reg=False, hue='is_exercise', legend=False, height=5, aspect=2)
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')
#plt.figure(figsize=(24,20))

# %%
axs[1]
